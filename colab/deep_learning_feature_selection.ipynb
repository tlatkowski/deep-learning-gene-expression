# %% [markdown]
# <a href="https://colab.research.google.com/github/tlatkowski/deep-learning-gene-expression/blob/master/colab/deep_learning_feature_selection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Download the code**

# %%
# !git clone https://github.com/tlatkowski/deep-learning-gene-expression.git
# Out:
# Cloning into 'deep-learning-gene-expression'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 113 (delta 3), reused 1 (delta 0), pack-reused 103
# Receiving objects: 100% (113/113), 43.37 MiB | 22.79 MiB/s, done.
# Resolving deltas: 100% (51/51), done.

# %%
ls -l
# Out:
# total 8
# drwxr-xr-x 9 root root 4096 Sep 16 07:54 deep-learning-gene-expression/
# drwxr-xr-x 1 root root 4096 Aug 27 16:17 sample_data/

# %% [markdown]
# **Install all mandatory requirements**

# %%
# !pip install -r deep-learning-gene-expression/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 12.2MB 4.9MB/s
# ...
#      |████████████████████████████████| 26.3MB 1.4MB/s
# ...
#      |████████████████████████████████| 51kB 24.8MB/s
# ...
#      |████████████████████████████████| 13.8MB 39.6MB/s
# ...
#      |████████████████████████████████| 12.4MB 41.4MB/s
# ...
#      |████████████████████████████████| 50.0MB 1.4MB/s
# ...
# ERROR: yellowbrick 0.9.1 has requirement scikit-learn>=0.20, but you'll have scikit-learn 0.19.1 which is incompatible.
# ERROR: tensorflow 1.14.0 has requirement numpy<2.0,>=1.14.5, but you'll have numpy 1.14.2 which is incompatible.
# ERROR: spacy 2.1.8 has requirement numpy>=1.15.0, but you'll have numpy 1.14.2 which is incompatible.
# ERROR: scikit-image 0.15.0 has requirement matplotlib!=3.0.0,>=2.0.0, but you'll have matplotlib 1.5.3 which is incompatible.
# ERROR: plotnine 0.5.1 has requirement matplotlib>=3.0.0, but you'll have matplotlib 1.5.3 which is incompatible.
# ...

# %%
# !pip freeze
# Out:
# absl-py==0.8.0
# alabaster==0.7.12
# albumentations==0.1.12
# altair==3.2.0
# astor==0.8.0
# astropy==3.0.5
# atari-py==0.1.15
# atomicwrites==1.3.0
# attrs==19.1.0
# audioread==2.1.8
# autograd==1.3
# Babel==2.7.0
# backcall==0.1.0
# backports.tempfile==1.0
# backports.weakref==1.0.post1
# beautifulsoup4==4.6.3
# bleach==3.1.0
# blis==0.2.4
# bokeh==1.0.4
# boto==2.49.0
# boto3==1.9.224
# botocore==1.12.224
# Bottleneck==1.2.1
# branca==0.3.1
# bs4==0.0.1
# bz2file==0.98
# cachetools==3.1.1
# certifi==2019.6.16
# cffi==1.12.3
# chainer==5.4.0
# chardet==3.0.4
# Click==7.0
# cloudpickle==0.6.1
# cmake==3.12.0
# community==1.0.0b1
# contextlib2==0.5.5
# convertdate==2.1.3
# coverage==3.7.1
# coveralls==0.5
# crcmod==1.7
# cvxopt==1.2.3
# cvxpy==1.0.25
# cycler==0.10.0
# cymem==2.0.2
# Cython==0.29.13
# daft==0.0.4
# dask==1.1.5
# dataclasses==0.6
# datascience==0.10.6
# decorator==4.4.0
# defusedxml==0.6.0
# descartes==1.1.0
# dill==0.3.0
# distributed==1.25.3
# Django==2.2.5
# ...

# %%
# !cp -r deep-learning-gene-expression/data/ .

# %%
ls -l
# Out:
# total 12
# drwxr-xr-x 2 root root 4096 Sep 16 08:38 data/
# drwxr-xr-x 9 root root 4096 Sep 16 07:54 deep-learning-gene-expression/
# drwxr-xr-x 1 root root 4096 Aug 27 16:17 sample_data/

# %% [markdown]
# **Run the pipeline**

# %%
# !python deep-learning-gene-expression/pipeline.py
# Out:
# INFO:selection.log_decorator:Running Correlation feature selection...
# INFO:selection.log_decorator:Running Fisher feature selection...
# INFO:selection.log_decorator:Running Ttest feature selection...
# INFO:selection.log_decorator:Running Random feature selection...
# INFO:__main__:Loading data...
# INFO:__main__:Loaded data...
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:utils.features_utils:Making feature selection with [fisher] method...
# INFO:selection.log_decorator:Read Fisher features from file : [features/Fisher.csv]...
# INFO:utils.features_utils:[fisher] feature selection last 18295 ms.
# INFO:utils.features_utils:Making feature selection with [corr] method...
# INFO:selection.log_decorator:Read Correlation features from file : [features/Correlation.csv]...
# INFO:utils.features_utils:[corr] feature selection last 21466 ms.
# INFO:utils.features_utils:Making feature selection with [ttest] method...
# ...
